# %% [markdown]
# # Matplotlib: Visualization with Python
#
# Matplotlib is a library used to create visualizations in python.
#
#
# ## Architecture of matplot lib: 3 layers
# #### Backend layer
# - Most complex
# - Built in classes
# - Figure canvas: area onto which the figure is drawn
# - Renderer: how to draw on the figure canvas
#
# #### Artist layer
#
# - Artist objects
#
#
# #### Scripting layer: Pyplot
#
# Pylplot is a library of functions that allow matplotlib to work like MATLAB. It's the scripting layer

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scatter plots
#
# Scatter plots are useful for showing the relationship (or lackthereof) between two variables. However, they aren't great when there's "noise" or outliers.

# %%
# How to p  lot two lists (the first is x, the second is y)

plt.plot([1700, 2100, 1900, 1300, 1600, 2200], [53000, 65000, 59000, 41000, 50000, 68000])

# %% [markdown]
# ### Pie charts
#
# Pie charts are useful for showing relative data and comparing the proportion of that date. They are used with categorial and quantitative data.

# %% [markdown]
# ## Line plots
#
# A line plot is a good choice for plotting continous data. For example, dates can be represented along the x-axis and the average length in minutes along the y-axis.
#
# Given that the data is continuous, a line plot would be a good choice, with the dates represented along the x-axis and the average length in minutes along the y-axis. This will allow us to easily spot any trends in movie durations. There are many ways to visualize data in Python, but matploblib.pyplot is one of the most common packages to do so.
#
# ### Plotting years and movie duration
#
# We would like to know the possible correlation between year and duration of a movie so we will create a line plot.
#
# This will allow us to easily spot any trends in movie duration.

# %%
# Pie chart with proportion of votes for four parties

# A sequence of strings that represent the labels for each wedge

labels = 'Party A', 'Party B', 'Party C', 'Party D'

# A list with the data. Each element in the list is presented proportionally

data = [175, 50, 25, 50]

fig1, ax1 = plt.subplots()

ax1.pie(data, labels=labels)

plt.show()

# %%
import pandas as pd

# Create the years and durations lists
years = list(range(2011,2021))
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# Create a dictionary with the two lists
movie_dict = dict(zip(years,durations))

durations_df = pd.DataFrame(list(movie_dict.items()),columns = ['years','durations'])

plt.plot(durations_df['years'], durations_df['durations'])


plt.show()
